# %% [markdown]
# # This notebook is the second part of the Toronto assignment in Capstone Project

# %%
#!pip install geocoder
#!pip install lxml
import geocoder # import geocoder
import pandas as pd

#steps done in the first part
Toronto_df = pd.read_html('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M')[0]
toronto_df = Toronto_df[Toronto_df.Borough != 'Not assigned'].reset_index(drop=True)
toronto_df.loc[toronto_df['Neighbourhood'] == 'Not assigned', 'Neighbourhood'] = toronto_df['Borough']
toronto_df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government

# %%
'''
It doesn't get out of the while loop :(

#making a list of postal codes
postal_codes = toronto_df['Postal Code'].tolist()

latitudes = []
longitudes = []

# initialize your variable to None
lat_lng_coords = None

# loop until you get the coordinates  # extra for loop to iterate over all postal codes
for postal_code in postal_codes:
    while (lat_lng_coords is None):
        g = geocoder.google('{}, Toronto, Ontario'.format(postal_code))
        lat_lng_coords = g.latlng
    
    print("Got the values.")
    latitudes.append(lat_lng_coords[0])
    longitudes.append(lat_lng_coords[1])

toronto_df['Latitudes'] = latitudes
toronto_df['Longitudes'] = longitudes
'''
# Out:
# '\n#making a list of postal codes\npostal_codes = toronto_df[\'Postal Code\'].tolist()\n\nlatitudes = []\nlongitudes = []\n\n# initialize your variable to None\nlat_lng_coords = None\n\n# loop until you get the coordinates  # extra for loop to iterate over all postal codes\nfor postal_code in postal_codes:\n    while (lat_lng_coords is None):\n        g = geocoder.google(\'{}, Toronto, Ontario\'.format(postal_code))\n        lat_lng_coords = g.latlng\n    \n    print("Got the values.")\n    latitudes.append(lat_lng_coords[0])\n    longitudes.append(lat_lng_coords[1])\n\ntoronto_df[\'Latitudes\'] = latitudes\ntoronto_df[\'Longitudes\'] = longitudes\n'

# %%
latlong_df = pd.read_csv('Geospatial_Coordinates.csv')

toronto_df['Latitude'] = latlong_df['Latitude']
toronto_df['Longitude'] = latlong_df['Longitude']

toronto_df.head()
# Out:
#   Postal Code           Borough                                Neighbourhood  \
# 0         M3A        North York                                    Parkwoods
# 1         M4A        North York                             Victoria Village
# 2         M5A  Downtown Toronto                    Regent Park, Harbourfront
# 3         M6A        North York             Lawrence Manor, Lawrence Heights
# 4         M7A  Downtown Toronto  Queen's Park, Ontario Provincial Government
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %%
toronto_df.shape
# Out:
# (103, 5)
