# %% [markdown]
# # This notebook will be used for the Capstone Project in the final course in Data Science specialization of IBM in Coursera.

# %%
import pandas as pd
import numpy as np

# %%
print("Hello Capstone ")
